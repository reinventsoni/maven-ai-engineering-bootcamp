# %% [markdown]
# ## OPENAI CLIENT

# %%
import os

api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    api_key = input("Enter your OpenAI API key: ")
    os.environ["OPENAI_API_KEY"] = api_key
    if not api_key:
        raise EnvironmentError("OpenAI API key not found")

# %%
import openai

# %%
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=[
        {'role': 'system', 'content': 'You are a helpfule assistant that can answer the questions'},
        {'role': 'user', 'content': 'Can you print 10 random words'}
    ]
)

print(response.choices[0].message.content)
# Out:
# Sure! Here are 10 random words:
#
# 1. Quokka
# 2. Prism
# 3. Euphoria
# 4. Wanderlust
# 5. Zephyr
# 6. Mosaic
# 7. Serenade
# 8. Nebula
# 9. Luminous
# 10. Solstice
#
# Let me know if you need anything else!

# %%
#response
#response.choices[0]
response.choices[0].message
response.choices[0].message.content
# Out:
# 'Sure! Here are 10 random words:\n\n1. Quokka\n2. Prism\n3. Euphoria\n4. Wanderlust\n5. Zephyr\n6. Mosaic\n7. Serenade\n8. Nebula\n9. Luminous\n10. Solstice\n\nLet me know if you need anything else!'

# %% [markdown]
# ## Google GenAI Client

# %%
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    api_key = input("Enter your Google API key: ")
    os.environ["GOOGLE_API_KEY"] = api_key
    if not api_key:
        raise EnvironmentError("Google API key not found")

# %%
from google import genai

# %%
genai_client = genai.Client(api_key=os.getenv("GOOGLE_API_KEY"))

# %%
response = genai_client.models.generate_content(
    model="gemini-2.0-flash",
    contents=["You are a helpful assistant", "Can you print 10 random words"]
)

print(response.text)
# Out:
# Okay, here are 10 random words:
#
# 1.  Effervescent
# 2.  Paradox
# 3.  Ubiquitous
# 4.  Zephyr
# 5.  Labyrinth
# 6.  Ephemeral
# 7.  Serendipity
# 8.  Mellifluous
# 9.  Quixotic
# 10. Resplendent

# %% [markdown]
# ## GROQ CLIENT

# %%
api_key = os.getenv("GROQ_API_KEY")
if not api_key:
    api_key = input("Enter your Groq API key: ")
    os.environ["GROQ_API_KEY"] = api_key
    if not api_key:
        raise EnvironmentError("Groq API key not found")

# %%
from groq import Groq

# %%
client = Groq(api_key=os.getenv("GROQ_API_KEY"))

# %%
response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
        {"role": "user", "content": "Can you print 10 random words"}
    ]
)

# %%
print(response.choices[0].message.content)
# Out:
# Here are 10 random words:
#
# 1. Cloud
# 2. Guitar
# 3. Space
# 4. Diamond
# 5. Helicopter
# 6. Library
# 7. Pineapple
# 8. Snowflake
# 9. Perfume
# 10. Computer
